# %% [markdown]
# <a href="https://colab.research.google.com/github/gulsung/VeriBilimi_1/blob/master/Python_VeriG%C3%B6rsellestirme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16],'r+')
plt.xlabel('tamsayılar')
plt.ylabel('tamsayıların kareleri')
plt.title('Bazı tamsayıların kareleri')
plt.show()

# %%
import numpy as np
t = np.arange(0.0, 5.0, 0.2)

plt.plot(t, t, 'ro--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
veri = {'a': np.arange(50),
        'c': np.random.randint(0,50,50),
        'd': np.random.randn(50)}
veri['b'] = veri['a'] + (10 * np.random.randn(50))
veri['d'] = np.abs(veri['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data = veri)
plt.xlabel('a sütunundaki veriler')
plt.ylabel('b sütunundaki veriler')
plt.show()

# %%
isimler = ['Ahmet', 'Mehmet', 'Ayşe', 'Fatma']
degerler = [5, 25, 50,100]

plt.figure(figsize=(9,3))

plt.subplot(131)
plt.bar(isimler, degerler)

plt.subplot(132)
plt.scatter(isimler, degerler)

plt.subplot(133)
plt.plot(isimler, degerler)

plt.suptitle('Birçok Farklı Grafik')
plt.show()

# %%
import numpy as np
t = np.arange(0.0, 5.0, 0.2)

plt.plot(t, t, 'r-', linewidth=2.0)
plt.show()

# %%
t = np.arange(0.0,5.0, 0.1)
plt.plot(t, (np.exp(-t) * np.cos(2 * np.pi * t)), 'k', t, (np.exp(-t) * np.cos(2 * np.pi * t)), 'bo')
plt.axis([0, 10, -1, 1])

plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2 * np.pi * t)

# fonksiyonun tanımlanması
def UydurmasyonFonksiyonHesapla(girdi_parametre1, girdi_parametre2):
    # birtakım işlemler
    return cikti_parametre1, cikti_parametre2, cikti_parametre3
    
# tanımlı fonksiyonun çağrılması
#cikti1, cikti2, cikti3 = UydurmasyonFonksiyonHesapla(girdi1, girdi2)

t = np.arange(0.0, 5.0, 0.1)
plt.plot(t, f(t), 'k', t, f(t), 'bo')
plt.axis([0, 10, -1, 1])
plt.show()

# %%
mu1 = 100
sigma1 = 15
x = mu1 + (sigma1 * np.random.randn(10000))

mu2 = 110
sigma2 = 10
y = mu2 + (sigma2 * np.random.randn(10000))

# söz konusu verilerin histogramı
n, bins, patches = plt.hist(x, 100, density = 1,facecolor='b', alpha=0.25)
n, bins, patches = plt.hist(y, 100, density = 1,facecolor='g', alpha=0.25)

plt.xlabel('Veriler')
plt.ylabel('Olasılıklar')
plt.title(r'Verilerin Histogramı: $\mu_1=100,\ \mu_2=110$')
plt.annotate('Gauss eğrisinin tepesi', xy=(110,0.04), xytext=(130,0.045),
             arrowprops=dict(facecolor='black', shrink=0.1))
plt.text(75, 0.025, r'$\mu_1=100,\ \sigma_1=15$')
plt.text(120, 0.035, r'$\mu_2=110,\ \sigma_2=10$')
plt.axis([40, 160, 0, 0.05])
plt.grid(True)
plt.show()

# %%
x = np.arange(0,10,0.01)
y = np.exp(x)

plt.figure()

plt.subplot(121)
plt.plot(x,y)
plt.yscale('linear')
plt.title('Lineer (Doğrusal)')
plt.grid(True)

plt.subplot(122)
plt.plot(x,y)
plt.yscale('log')
plt.title('Logaritmik')
plt.grid(True)

# plt.subpLots_adjust(top=0.98, Left=0.02, right=0.98, hspace=0.)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
veri = pd.read_csv("olimpiyatlar.csv.csv")
veri.head()
# Out:
#                                                                                                   es Freestyle Relay  \
# Eizo Kenmotsu M 20.0 161.0 57.0 Japan JPN 1968 Summer Mexico City Gymnastics        Gymnastics Men's Team All-Around
#                                                                   Gymnastics         Gymnastics Men's Horizontal Bar
#                 24.0 161.0 57.0 Japan JPN 1972 Summer Munich      Gymnastics  Gymnastics Men's Individual All-Around
#                                                                   Gymnastics        Gymnastics Men's Team All-Around
#                                                                   Gymnastics          Gymnastics Men's Parallel Bars
#
#                                                                               Silver
# Eizo Kenmotsu M 20.0 161.0 57.0 Japan JPN 1968 Summer Mexico City Gymnastics    Gold
#                                                                   Gymnastics  Bronze
#                 24.0 161.0 57.0 Japan JPN 1972 Summer Munich      Gymnastics  Silver
#                                                                   Gymnastics    Gold
#                                                                   Gymnastics  Bronze

# %%
# saçılım grafiği
def sacilimGrafikCiz():
    sns.scatterplot(x='boy', y='kilo', data=veri)
    plt.title('Boy ve Ağırlık İlişkisi - Beyaz Izgara Tema')
    plt.show()

sacilimGrafikCiz()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-05610b1c3671> in <module>
#       5     plt.show()
#       6
# ----> 7 sacilimGrafikCiz()
#
# <ipython-input-61-05610b1c3671> in sacilimGrafikCiz()
#       1 # saçılım grafiği
#       2 def sacilimGrafikCiz():
# ----> 3     sns.scatterplot(x='boy', y='kilo', data=veri)
#       4     plt.title('Boy ve Ağırlık İlişkisi - Beyaz Izgara Tema')
#       5     plt.show()
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
#     810         x_bins=x_bins, y_bins=y_bins,
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `boy` for parameter `x`

# %%
sns.set_style("darkgrid")
sacilimGrafikCiz()

# %%
sns.set_style("whitegrid")
sacilimGrafikCiz()

# %%
# saçılım grafiği -kategorik
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri)
plt.title('Madalayaya Göre Boy ve Ağırlık Dağılımı')
plt.show()

# %%
sns.set_style("whitegrid")

sns.scatterplot(x='boy', y='kilo', hue='cinsiyet', style='madalya', data=veri)
plt.xlabel=('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("whitegrid")

sns.scatterplot(x='boy', y='kilo', hue='cinsiyet', style='madalya', size='yas',sizes=(15,200), data=veri)
plt.xlabel=('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
# Saçılım Grafiği-Doğrusal Regresyon
sns.regplot(x='boy', y='kilo', data=veri, marker='+', scatter_kws={'alpha':0.2})
plt.title('Boy ve Ağırlık Dağılımı')
plt.show()

# %%
# Renk Paletleri

sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette='Set1')
plt.title('Madalya Göre Boy ve Ağırlık Dağılımı')
plt.show()

# %%
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette='rocket')
plt.title('Madalya Göre Boy ve Ağırlık Dağılımı')
plt.show()

# %%
#çizgi grafiği
sns.lineplot(x='boy', y='kilo', data=veri)
plt.title('Boy ve Kilo')
plt.show()

# %%
#Çizgi grafiği-kategorik
sns.lineplot(x='boy', y='kilo', hue='cinsiyet', data=veri)
plt.title('Cinsiyete Göre Boy ve Ağırlık İlişkileri')
plt.show()

# %%
#histogram
sns.displot(veri, x='kilo')
plt.ylabel("Frekans")
plt.title("Cinsiyete Göre Ayrıştırılmış Ağırlık Histogramı")
plt.show()

# %%
sns.displot(veri, x="kilo", col="cinsiyet", multiple="dodge")
plt.show()

# %%
sns.displot(veri, x="kilo", y="boy", kind="kde")
#plt.xlabel("Ağırlık")
plt.ylabel("Boy")
plt.title("Ağırlık-Boy Histagramı")
plt.show()
